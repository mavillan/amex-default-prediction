# %%
import gc
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

import category_encoders as ce
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics

import sys
sys.path.append("../utils")
from metrics import compute_recall_at4, compute_normalized_gini, compute_amex_metric

pd.set_option('display.max_columns', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# metrics in lgbm format

def metric_recall_at4(y_pred: np.ndarray, data: lgb.Dataset):
    y_true = data.get_label()
    return 'recall_at4', compute_recall_at4(y_true, y_pred), True

def metric_normalized_gini(y_pred: np.ndarray, data: lgb.Dataset):
    y_true = data.get_label()
    return 'norm_gini', compute_normalized_gini(y_true, y_pred), True

def metric_amex(y_pred: np.ndarray, data: lgb.Dataset):
    y_true = data.get_label()
    return 'amex_metric', compute_amex_metric(y_true, y_pred), True

# %%
# CONFIG PARAMS
N_REPEATS = 1

PATH_PL_INPUT = sorted(glob("../data/subs/lgbm-bce-dsv02-pl/pl/*"))[-1]
print(PATH_PL_INPUT)

current_iter = int(PATH_PL_INPUT.split("iter")[-1]) + 1
PATH_PL_OUTPUT = f"{PATH_PL_INPUT.split('iter')[0]}iter{current_iter}"
print(PATH_PL_OUTPUT)
# Out:
# ../data/subs/lgbm-bce-dsv02-pl/pl/iter0
# ../data/subs/lgbm-bce-dsv02-pl/pl/iter1

# %% [markdown]
# ***
# ## load and prepare data

# %%
# !ls ../data/processed/dsv02
# Out:
# dataset-metadata.json  test.parquet  train.parquet

# %%
train = pd.read_parquet("../data/processed/dsv02/train.parquet")
train_labels = pd.read_csv("../data/raw/train_labels.csv", index_col="customer_ID")

# %%
input_feats = train.columns.tolist()
categ_feats = [
    'B_30_last', 'B_38_last', 'D_114_last', 'D_116_last', 'D_117_last', 
    'D_120_last', 'D_126_last', 'D_63_last', 'D_64_last', 'D_66_last', 'D_68_last',
]

# %%
train = pd.merge(train, train_labels, how="inner", left_index=True, right_index=True)
train = train.reset_index()

del train_labels
gc.collect()
# Out:
# 72

# %% [markdown]
# ***
# ## model training
#
# train with repeated cross validation

# %%
test = pd.read_parquet("../data/processed/dsv02/test.parquet")
sub = pd.read_csv("../data/raw/sample_submission.csv")

# %%
model_params = {
    'objective': 'cross_entropy',
    'metric': 'None',
    'learning_rate': 0.05,
    'num_leaves': 64,
    'force_col_wise': True,
    'bagging_freq': 1,
    'seed': 2112,
    'verbosity': 0,
    'first_metric_only': True,
    'bin_construct_sample_cnt': 100000000,
    'feature_pre_filter': False,
    'bagging_fraction': 0.9,
    'feature_fraction': 0.2,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'min_data_in_leaf': 1000,
    'path_smooth': 10,
    'max_bin': 127,
}

# %%
def train_models(dataframe: pd.DataFrame, test: pd.DataFrame, path_pl: str, n_folds: int = 5) -> tuple:
    
    dataframe["w"] = 1
    models = list()
    
    # dataframe to store the oof predictions
    oof = dataframe[["target"]].copy()
    oof["pred"] = -1

    for fold in range(n_folds):
        
        print(f" training model {fold+1}/{n_folds} ".center(100, "#"))
        
        train_df = dataframe.query("fold != @fold")
        valid_df = dataframe.query("fold == @fold")
        
        # adds the pseudo labels
        pseudo_labels = pd.read_parquet(f"{path_pl}/pl-fold{fold}.parquet")
        pseudo_labels.rename({"prediction":"target"}, axis=1, inplace=True)
        _test = pd.merge(test, pseudo_labels, how="inner", left_index=True, right_index=True)
        _test["w"] = (_test.target - 0.5).abs().values
        
        train_df = pd.concat([
            train_df[input_feats+["w","target"]],
            _test[input_feats+["w","target"]],
            ],
            ignore_index=True
        )
        
        train_dset = lgb.Dataset(
            data=train_df.loc[:,input_feats],
            label=train_df.loc[:,"target"].values,
            weight=train_df.loc[:,"w"].values,
            categorical_feature=categ_feats,
            free_raw_data=True
        )
        valid_dset = lgb.Dataset(
            data=valid_df.loc[:,input_feats],
            label=valid_df.loc[:,"target"].values,
            categorical_feature=categ_feats,
            free_raw_data=True
        )
        
        model = lgb.train(
            params=model_params,
            train_set=train_dset,
            valid_sets=[valid_dset,],
            feval=[metric_amex, metric_recall_at4, metric_normalized_gini],
            num_boost_round=3000,
            callbacks=[lgb.log_evaluation(period=50), lgb.early_stopping(100)],
        )
        
        lgb.plot_importance(model, figsize=(8,15), importance_type="split", max_num_features=30)
        lgb.plot_importance(model, figsize=(8,15), importance_type="gain", max_num_features=30)
        plt.show()
        
        oof.loc[valid_df.index,"pred"] = model.predict(valid_df.loc[:,input_feats])
            
        models.append(model)
        del train_df,_test,pseudo_labels
        del train_dset,valid_dset
        gc.collect()
    
    return models,oof

# %%
# implement repeated cross validation
glob("../data/processed/cv*.parquet")
# Out:
# ['../data/processed/cv1.parquet',
#  '../data/processed/cv2.parquet',
#  '../data/processed/cv4.parquet',
#  '../data/processed/cv0.parquet',
#  '../data/processed/cv3.parquet']

# %%
# %%time 

all_models = list()
all_oof_dfs = list()

for repetition in range(N_REPEATS):
    print(f" repeated cross-validation step: {repetition+1}/{N_REPEATS} ".center(100, "#"))
    
    path_pl = f"{PATH_PL_INPUT}/cv{repetition}"
    print("path_pl:", path_pl)
    
    if "fold" in train.columns:
        train.drop("fold", axis=1, inplace=True)
    folds = pd.read_parquet(f'../data/processed/cv{repetition}.parquet')
    train = pd.merge(train, folds, how="inner", on="customer_ID")
    
    tic = time.time()
    models,oof = train_models(train, test, path_pl=path_pl)
    tac = time.time()
    print(f"Training time: {(tac-tic)/60} min.")
          
    # oof metrics
    print("OOF recall_at4:", compute_recall_at4(oof.target.values, oof.pred.values))
    print("OOF normalized_gini:", compute_normalized_gini(oof.target.values, oof.pred.values))
    print("OOF competition metric:", compute_amex_metric(oof.target.values, oof.pred.values))
          
    all_models.extend(models)
    all_oof_dfs.append(oof)
          
    del folds; gc.collect()
# Out:
# ############################### repeated cross-validation step: 1/1 ################################
# path_pl: ../data/subs/lgbm-bce-dsv02-pl/pl/iter0/cv0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ######################################## training model 1/5 ########################################
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# Training until validation scores don't improve for 100 rounds
# [50]	valid_0's amex_metric: 0.768458	valid_0's recall_at4: 0.625221	valid_0's norm_gini: 0.911695
# [100]	valid_0's amex_metric: 0.781858	valid_0's recall_at4: 0.645712	valid_0's norm_gini: 0.918004
# [150]	valid_0's amex_metric: 0.787908	valid_0's recall_at4: 0.654927	valid_0's norm_gini: 0.920888
# [200]	valid_0's amex_metric: 0.789878	valid_0's recall_at4: 0.657494	valid_0's norm_gini: 0.922261
# [250]	valid_0's amex_metric: 0.790995	valid_0's recall_at4: 0.659009	valid_0's norm_gini: 0.922982
# [300]	valid_0's amex_metric: 0.792227	valid_0's recall_at4: 0.660986	valid_0's norm_gini: 0.923467
# [350]	valid_0's amex_metric: 0.792398	valid_0's recall_at4: 0.660944	valid_0's norm_gini: 0.923852
# [400]	valid_0's amex_metric: 0.792773	valid_0's recall_at4: 0.661449	valid_0's norm_gini: 0.924097
# [450]	valid_0's amex_metric: 0.79291	valid_0's recall_at4: 0.661575	valid_0's norm_gini: 0.924244
# [500]	valid_0's amex_metric: 0.792952	valid_0's recall_at4: 0.661575	valid_0's norm_gini: 0.924329
# [550]	valid_0's amex_metric: 0.793692	valid_0's recall_at4: 0.662964	valid_0's norm_gini: 0.92442
# [600]	valid_0's amex_metric: 0.794308	valid_0's recall_at4: 0.6641	valid_0's norm_gini: 0.924515
# [650]	valid_0's amex_metric: 0.79418	valid_0's recall_at4: 0.663763	valid_0's norm_gini: 0.924597
# [700]	valid_0's amex_metric: 0.794486	valid_0's recall_at4: 0.66431	valid_0's norm_gini: 0.924662
# [750]	valid_0's amex_metric: 0.794657	valid_0's recall_at4: 0.664605	valid_0's norm_gini: 0.924709
# [800]	valid_0's amex_metric: 0.795251	valid_0's recall_at4: 0.665783	valid_0's norm_gini: 0.924719
# [850]	valid_0's amex_metric: 0.795156	valid_0's recall_at4: 0.665573	valid_0's norm_gini: 0.92474
# [900]	valid_0's amex_metric: 0.794758	valid_0's recall_at4: 0.664731	valid_0's norm_gini: 0.924784
# Early stopping, best iteration is:
# [822]	valid_0's amex_metric: 0.795507	valid_0's recall_at4: 0.666246	valid_0's norm_gini: 0.924768
# ######################################## training model 2/5 ########################################
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# Training until validation scores don't improve for 100 rounds
# [50]	valid_0's amex_metric: 0.765042	valid_0's recall_at4: 0.619961	valid_0's norm_gini: 0.910123
# [100]	valid_0's amex_metric: 0.77826	valid_0's recall_at4: 0.640116	valid_0's norm_gini: 0.916403
# [150]	valid_0's amex_metric: 0.784446	valid_0's recall_at4: 0.649205	valid_0's norm_gini: 0.919687
# [200]	valid_0's amex_metric: 0.78754	valid_0's recall_at4: 0.653707	valid_0's norm_gini: 0.921373
# [250]	valid_0's amex_metric: 0.789395	valid_0's recall_at4: 0.656442	valid_0's norm_gini: 0.922348
# [300]	valid_0's amex_metric: 0.791317	valid_0's recall_at4: 0.659724	valid_0's norm_gini: 0.922911
# [350]	valid_0's amex_metric: 0.791905	valid_0's recall_at4: 0.660565	valid_0's norm_gini: 0.923245
# [400]	valid_0's amex_metric: 0.792536	valid_0's recall_at4: 0.661575	valid_0's norm_gini: 0.923496
# [450]	valid_0's amex_metric: 0.79243	valid_0's recall_at4: 0.661155	valid_0's norm_gini: 0.923705
# [500]	valid_0's amex_metric: 0.79247	valid_0's recall_at4: 0.661112	valid_0's norm_gini: 0.923827
# [550]	valid_0's amex_metric: 0.792301	valid_0's recall_at4: 0.66065	valid_0's norm_gini: 0.923953
# Early stopping, best iteration is:
# [473]	valid_0's amex_metric: 0.793276	valid_0's recall_at4: 0.662796	valid_0's norm_gini: 0.923756
# ######################################## training model 3/5 ########################################
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# Training until validation scores don't improve for 100 rounds
# [50]	valid_0's amex_metric: 0.761023	valid_0's recall_at4: 0.612808	valid_0's norm_gini: 0.909238
# [100]	valid_0's amex_metric: 0.772999	valid_0's recall_at4: 0.630901	valid_0's norm_gini: 0.915097
# [150]	valid_0's amex_metric: 0.778804	valid_0's recall_at4: 0.639527	valid_0's norm_gini: 0.91808
# [200]	valid_0's amex_metric: 0.781776	valid_0's recall_at4: 0.643903	valid_0's norm_gini: 0.919649
# [250]	valid_0's amex_metric: 0.783396	valid_0's recall_at4: 0.646259	valid_0's norm_gini: 0.920532
# [300]	valid_0's amex_metric: 0.783876	valid_0's recall_at4: 0.64668	valid_0's norm_gini: 0.921073
# [350]	valid_0's amex_metric: 0.784204	valid_0's recall_at4: 0.647017	valid_0's norm_gini: 0.921391
# [400]	valid_0's amex_metric: 0.785663	valid_0's recall_at4: 0.64971	valid_0's norm_gini: 0.921617
# [450]	valid_0's amex_metric: 0.785248	valid_0's recall_at4: 0.648742	valid_0's norm_gini: 0.921753
# Early stopping, best iteration is:
# [375]	valid_0's amex_metric: 0.785839	valid_0's recall_at4: 0.650173	valid_0's norm_gini: 0.921506
# ######################################## training model 4/5 ########################################
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# Training until validation scores don't improve for 100 rounds
# [50]	valid_0's amex_metric: 0.761874	valid_0's recall_at4: 0.614307	valid_0's norm_gini: 0.909442
# [100]	valid_0's amex_metric: 0.773031	valid_0's recall_at4: 0.630549	valid_0's norm_gini: 0.915513
# [150]	valid_0's amex_metric: 0.778408	valid_0's recall_at4: 0.63825	valid_0's norm_gini: 0.918567
# [200]	valid_0's amex_metric: 0.781982	valid_0's recall_at4: 0.643804	valid_0's norm_gini: 0.92016
# [250]	valid_0's amex_metric: 0.783699	valid_0's recall_at4: 0.646287	valid_0's norm_gini: 0.921111
# [300]	valid_0's amex_metric: 0.784642	valid_0's recall_at4: 0.647549	valid_0's norm_gini: 0.921735
# [350]	valid_0's amex_metric: 0.786195	valid_0's recall_at4: 0.650242	valid_0's norm_gini: 0.922148
# [400]	valid_0's amex_metric: 0.786251	valid_0's recall_at4: 0.650074	valid_0's norm_gini: 0.922428
# [450]	valid_0's amex_metric: 0.786612	valid_0's recall_at4: 0.650621	valid_0's norm_gini: 0.922604
# Early stopping, best iteration is:
# [359]	valid_0's amex_metric: 0.786622	valid_0's recall_at4: 0.651041	valid_0's norm_gini: 0.922203
# ######################################## training model 5/5 ########################################
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# Training until validation scores don't improve for 100 rounds
# [50]	valid_0's amex_metric: 0.768984	valid_0's recall_at4: 0.625205	valid_0's norm_gini: 0.912762
# [100]	valid_0's amex_metric: 0.780709	valid_0's recall_at4: 0.642584	valid_0's norm_gini: 0.918833
# [150]	valid_0's amex_metric: 0.788726	valid_0's recall_at4: 0.655544	valid_0's norm_gini: 0.921908
# [200]	valid_0's amex_metric: 0.791409	valid_0's recall_at4: 0.659415	valid_0's norm_gini: 0.923402
# [250]	valid_0's amex_metric: 0.7937	valid_0's recall_at4: 0.663118	valid_0's norm_gini: 0.924281
# [300]	valid_0's amex_metric: 0.795543	valid_0's recall_at4: 0.666274	valid_0's norm_gini: 0.924813
# [350]	valid_0's amex_metric: 0.796559	valid_0's recall_at4: 0.667957	valid_0's norm_gini: 0.925161
# [400]	valid_0's amex_metric: 0.797216	valid_0's recall_at4: 0.669009	valid_0's norm_gini: 0.925423
# [450]	valid_0's amex_metric: 0.797854	valid_0's recall_at4: 0.670145	valid_0's norm_gini: 0.925563
# [500]	valid_0's amex_metric: 0.797258	valid_0's recall_at4: 0.668883	valid_0's norm_gini: 0.925633
# [550]	valid_0's amex_metric: 0.797967	valid_0's recall_at4: 0.670187	valid_0's norm_gini: 0.925747
# [600]	valid_0's amex_metric: 0.797883	valid_0's recall_at4: 0.669935	valid_0's norm_gini: 0.925832
# [650]	valid_0's amex_metric: 0.798316	valid_0's recall_at4: 0.670734	valid_0's norm_gini: 0.925899
# [700]	valid_0's amex_metric: 0.799153	valid_0's recall_at4: 0.672375	valid_0's norm_gini: 0.925932
# [750]	valid_0's amex_metric: 0.798447	valid_0's recall_at4: 0.670945	valid_0's norm_gini: 0.92595
# [800]	valid_0's amex_metric: 0.798526	valid_0's recall_at4: 0.671113	valid_0's norm_gini: 0.92594
# Early stopping, best iteration is:
# [707]	valid_0's amex_metric: 0.799321	valid_0's recall_at4: 0.672712	valid_0's norm_gini: 0.925931
# Training time: 27.947066489855448 min.
# OOF recall_at4: 0.6594573669505503
# OOF normalized_gini: 0.9231763430880424
# OOF competition metric: 0.7913168550192964
# CPU times: user 2h 56min 53s, sys: 1min 3s, total: 2h 57min 56s
# Wall time: 29min 55s

# %%
results = list()

for oof in all_oof_dfs:  
    r = {
        "recall_at4": compute_recall_at4(oof.target.values, oof.pred.values),
        "gini": compute_normalized_gini(oof.target.values, oof.pred.values),
        "metric": compute_amex_metric(oof.target.values, oof.pred.values),
    }
    results.append(r)

results = pd.DataFrame(results)
display(results)

print("\nmean:")
display(results.mean(axis=0))

print("\nstd:")
display(results.std(axis=0))
# Out:
#    recall_at4      gini    metric
# 0    0.659457  0.923176  0.791317
# mean:
# recall_at4    0.659457
# gini          0.923176
# metric        0.791317
# dtype: float64
# std:
# recall_at4   NaN
# gini         NaN
# metric       NaN
# dtype: float64

# %%
del train,test
gc.collect()
# Out:
# 23

# %% [markdown]
# ***
# ## make predictions and submit

# %%
test = pd.read_parquet("../data/processed/dsv02/test.parquet")
sub = pd.read_csv("../data/raw/sample_submission.csv")

# %%
def make_predictions(dataframe:pd.DataFrame, input_feats:list, models:list) -> np.array:
    preds = [model.predict(dataframe[input_feats]) for model in models]
    return np.mean(preds, axis=0)

# %%
# %%time

save_pl = True
path_pl = "../data/subs/lgbm-bce-dsv02-pl/pl/iter0"
all_preds = list()

for repetition in range(N_REPEATS):
    if "prediction" in sub.columns:
        sub.drop("prediction", axis=1, inplace=True)
    if "prediction" in test.columns:
        test.drop("prediction", axis=1, inplace=True)
        
    imin = repetition*5
    imax = (repetition+1)*5
    
    preds = list()
    for fold,idx in enumerate(range(imin, imax)):
        pred = all_models[idx].predict(test[input_feats])
        if save_pl:
            test["prediction"] = pred
            test[["prediction"]].to_parquet(f"{path_pl}/cv{repetition}/pl-fold{fold}.parquet")
        preds.append(pred)
    all_preds.extend(preds)
            
    test["prediction"] = np.mean(preds, axis=0)
    sub["prediction"] = test.loc[sub.customer_ID.values,"prediction"].values
    assert sub.prediction.isna().sum() == 0
    sub.to_csv(f"../data/subs/lgbm-bce-dsv02/submission-cv{repetition}.csv", index=False)

# %%
# %%time
# predict using all the trained models
if "prediction" in sub.columns:
    sub.drop("prediction", axis=1, inplace=True)
if "prediction" in test.columns:
    test.drop("prediction", axis=1, inplace=True)

test["prediction"] = np.mean(all_preds, axis=0)
sub["prediction"] = test.loc[sub.customer_ID.values,"prediction"].values
assert sub.prediction.isna().sum() == 0
sub.to_csv(f"../data/subs/lgbm-bce-dsv02/submission-all.csv", index=False)

# %% [markdown]
# ***
